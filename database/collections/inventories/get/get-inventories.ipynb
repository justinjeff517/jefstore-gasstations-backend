# %%
from pymongo import MongoClient
import os
from dotenv import load_dotenv
from bson.json_util import dumps  # <-- handles datetime, ObjectId, Decimal128, etc.

load_dotenv()

uri = os.getenv("MONGODB_URI")
database = os.getenv("MONGODB_DATABASE")
collection = "inventories"

client = MongoClient(uri)
db = client[database]
coll = db[collection]

inventories = list(coll.find({}, {"_id": 0}))

# Pretty print JSON (Mongo-safe)
print(dumps(inventories, indent=2))
# Out:
# [
#   {
#     "id": "9f3a27e6-1b52-4e0b-bc6e-62c1f2a7c8b9",
#     "previous_form_qr_code": "20251011",
#     "current_form_qr_code": "20251012",
#     "date": "2025-10-12",
#     "location": "JEF Gas Station \u2013 Sikatuna Branch",
#     "tin": "123-456-789",
#     "branch": "JEF Biosciences Fuel Division",
#     "created": {
#       "$date": 1760256000000
#     },
#     "items": [
#       {
#         "item_number": "1",
#         "id": "d220eb40-db76-4517-9eb8-702abbc1767f",
#         "created": {
#           "$date": 1760256000000
#         },
#         "updated": {
#           "$date": 1760256000000
#         },
#         "barcode": "4809992000101",
#         "type": "fuel",
#         "name": "Premium Gasoline",
#         "price": 69.5,
#         "unit": "liter",
#         "previous_quantity": 520,
#         "addstock": 300,
#         "sold": 250,
#         "current_quantity": 570
#       },
#       {
#         "item_number": "2",
#         "id": "bf2e6601-90a0-486f-a005-d3127a49d9d4",
#         "created": {
#           "$date": 1760256000000
#         },
#         "updated": {
#           "$date": 1760256000000
#         },
#         "barcode": "4809992000102",
#         "type": "fuel",
#         "name": "Regular Gasoline",
#         "price": 64.75,
#         "unit": "liter",
#         "previous_quantity": 680,
#         "addstock": 400,
#         "sold": 320,
#         "current_quantity": 760
#       },
#       {
#         "item_number": "3",
#         "id": "f277e293-0368-46d7-bcda-eb9000fe9000",
#         "created": {
#           "$date": 1760256000000
#         },
#         "updated": {
#           "$date": 1760256000000
#         },
#         "barcode": "4809992000103",
#         "type": "fuel",
#         "name": "Premium Diesel",
#         "price": 61.2,
#         "unit": "liter",
#         "previous_quantity": 450,
#         "addstock": 350,
#         "sold": 280,
#         "current_quantity": 520
#       },
#       {
#         "item_number": "4",
#         "id": "a336d913-612a-4276-95db-c7343eb342fd",
#         "created": {
#           "$date": 1760256000000
#         },
#         "updated": {
#           "$date": 1760256000000
#         },
#         "barcode": "4809992000201",
#         "type": "lubricant",
#         "name": "Engine Oil SAE 40",
#         "price": 250.0,
#         "unit": "liter",
#         "previous_quantity": 60,
#         "addstock": 40,
#         "sold": 25,
#         "current_quantity": 75
#       },
#       {
#         "item_number": "5",
#         "id": "eda8b3f8-dc4f-4afb-ba20-5e7d3424da8e",
#         "created": {
#           "$date": 1760256000000
#         },
#         "updated": {
#           "$date": 1760256000000
#         },
#         "barcode": "4809992000202",
#         "type": "lubricant",
#         "name": "Automatic Transmission Fluid (ATF)",
#         "price": 310.0,
#         "unit": "liter",
#         "previous_quantity": 50,
#         "addstock": 30,
#         "sold": 20,
#         "current_quantity": 60
#       },
#       {
#         "item_number": "6",
#         "id": "e0c8984b-36b9-4742-bf51-954599a82aa7",
#         "created": {
#           "$date": 1760256000000
#         },
#         "updated": {
#           "$date": 1760256000000
#         },
#         "barcode": "4809992000203",
#         "type": "lubricant",
#         "name": "Gear Oil EP 90",
#         "price": 285.0,
#         "unit": "liter",
#         "previous_quantity": 45,
#         "addstock": 25,
#         "sold": 15,
#         "current_quantity": 55
#       },
#       {
#         "item_number": "7",
#         "id": "169105f8-2413-4247-a67a-efd79a543a72",
#         "created": {
#           "$date": 1760256000000
#         },
#         "updated": {
#           "$date": 1760256000000
#         },
#         "barcode": "4809992000204",
#         "type": "lubricant",
#         "name": "Hydraulic Oil ISO 68",
#         "price": 295.0,
#         "unit": "liter",
#         "previous_quantity": 35,
#         "addstock": 25,
#         "sold": 10,
#         "current_quantity": 50
#       },
#       {
#         "item_number": "8",
#         "id": "4ae24feb-f9fe-41aa-9d4e-fc6e643bbac6",
#         "created": {
#           "$date": 1760256000000
#         },
#         "updated": {
#           "$date": 1760256000000
#         },
#         "barcode": "4809992000205",
#         "type": "lubricant",
#         "name": "2T Motorcycle Oil",
#         "price": 180.0,
#         "unit": "liter",
#         "previous_quantity": 80,
#         "addstock": 60,
#         "sold": 45,
#         "current_quantity": 95
#       }
#     ],
#     "cashier": "Liam Santos",
#     "cashier_employee_number": "50321",
#     "recorder": "Ella Reyes",
#     "recorder_employee_number": "50325",
#     "is_empty": false
#   },
#   {
#     "id": "edfa2b5e-657e-4616-990b-1b69c983ee86",
#     "previous_form_qr_code": "20251012",
#     "current_form_qr_code": "87654321",
#     "date": "2025-10-13",
#     "location": "JEF Gas Station \u2013 Sikatuna Branch",
#     "tin": "123-456-789",
#     "branch": "JEF Biosciences Fuel Division",
#     "created": {
#       "$date": 1760457682654
#     },
#     "items": [
#       {
#         "item_number": "1",
#         "id": "249f4956-70a7-4557-ad9a-95a400bb0f47",
#         "created": {
#           "$date": 1760457682654
#         },
#         "updated": {
#           "$date": 1760457682654
#         },
#         "barcode": "4809992000101",
#         "type": "fuel",
#         "name": "Premium Gasoline",
#         "price": 69.5,
#         "unit": "liter",
#         "previous_quantity": 570,
#         "addstock": 0,
#         "sold": 0,
#         "current_quantity": 0
#       },
#       {
#         "item_number": "2",
#         "id": "1e3fd320-4920-49d0-858f-654fa5c5b6b0",
#         "created": {
#           "$date": 1760457682654
#         },
#         "updated": {
#           "$date": 1760457682654
#         },
#         "barcode": "4809992000102",
#         "type": "fuel",
#         "name": "Regular Gasoline",
#         "price": 64.75,
#         "unit": "liter",
#         "previous_quantity": 760,
#         "addstock": 0,
#         "sold": 0,
#         "current_quantity": 0
#       },
#       {
#         "item_number": "3",
#         "id": "c573a94c-3ab9-4716-b829-a6ff21f33502",
#         "created": {
#           "$date": 1760457682654
#         },
#         "updated": {
#           "$date": 1760457682654
#         },
#         "barcode": "4809992000103",
#         "type": "fuel",
#         "name": "Premium Diesel",
#         "price": 61.2,
#         "unit": "liter",
#         "previous_quantity": 520,
#         "addstock": 0,
#         "sold": 0,
#         "current_quantity": 0
#       },
#       {
#         "item_number": "4",
#         "id": "f9e0310a-6343-4570-8e40-4b17de9233ea",
#         "created": {
#           "$date": 1760457682654
#         },
#         "updated": {
#           "$date": 1760457682654
#         },
#         "barcode": "4809992000201",
#         "type": "lubricant",
#         "name": "Engine Oil SAE 40",
#         "price": 250.0,
#         "unit": "liter",
#         "previous_quantity": 75,
#         "addstock": 0,
#         "sold": 0,
#         "current_quantity": 0
#       },
#       {
#         "item_number": "5",
#         "id": "8b9ba29c-d7a7-4dc0-b8c0-190e3a1598c1",
#         "created": {
#           "$date": 1760457682654
#         },
#         "updated": {
#           "$date": 1760457682654
#         },
#         "barcode": "4809992000202",
#         "type": "lubricant",
#         "name": "Automatic Transmission Fluid (ATF)",
#         "price": 310.0,
#         "unit": "liter",
#         "previous_quantity": 60,
#         "addstock": 0,
#         "sold": 0,
#         "current_quantity": 0
#       },
#       {
#         "item_number": "6",
#         "id": "2970e78e-70aa-442a-af99-47eb157155d4",
#         "created": {
#           "$date": 1760457682654
#         },
#         "updated": {
#           "$date": 1760457682654
#         },
#         "barcode": "4809992000203",
#         "type": "lubricant",
#         "name": "Gear Oil EP 90",
#         "price": 285.0,
#         "unit": "liter",
#         "previous_quantity": 55,
#         "addstock": 0,
#         "sold": 0,
#         "current_quantity": 0
#       },
#       {
#         "item_number": "7",
#         "id": "ab351727-937c-41ed-bea1-0f2afde3dfee",
#         "created": {
#           "$date": 1760457682654
#         },
#         "updated": {
#           "$date": 1760457682654
#         },
#         "barcode": "4809992000204",
#         "type": "lubricant",
#         "name": "Hydraulic Oil ISO 68",
#         "price": 295.0,
#         "unit": "liter",
#         "previous_quantity": 50,
#         "addstock": 0,
#         "sold": 0,
#         "current_quantity": 0
#       },
#       {
#         "item_number": "8",
#         "id": "d1cb8d3c-9d54-4f18-879b-59c46beb7ab4",
#         "created": {
#           "$date": 1760457682654
#         },
#         "updated": {
#           "$date": 1760457682654
#         },
#         "barcode": "4809992000205",
#         "type": "lubricant",
#         "name": "2T Motorcycle Oil",
#         "price": 180.0,
#         "unit": "liter",
#         "previous_quantity": 95,
#         "addstock": 0,
#         "sold": 0,
#         "current_quantity": 0
#       }
#     ],
#     "is_empty": true
#   }
# ]
