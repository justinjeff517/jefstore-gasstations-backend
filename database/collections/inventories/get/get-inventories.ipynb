# %%
from pymongo import MongoClient
import os
from dotenv import load_dotenv
from bson.json_util import dumps  # <-- handles datetime, ObjectId, Decimal128, etc.

load_dotenv()

uri = os.getenv("MONGODB_URI")
database = os.getenv("MONGODB_DATABASE")
collection = "inventories"

client = MongoClient(uri)
db = client[database]
coll = db[collection]

inventories = list(coll.find({}, {"_id": 0}))

# Pretty print JSON (Mongo-safe)
print(dumps(inventories, indent=2))
# Out:
# [
#   {
#     "id": "9f3a27e6-1b52-4e0b-bc6e-62c1f2a7c8b9",
#     "previous_form_qr_code": "20251011",
#     "generated_by": "Ella Reyes",
#     "generator_employee_number": "50325",
#     "current_form_qr_code": "20251012",
#     "date": "2025-10-12",
#     "location": "JEF Gas Station \u2013 Sikatuna Branch",
#     "tin": "123-456-789",
#     "branch": "JEF Biosciences Fuel Division",
#     "created": {
#       "$date": 1760256000000
#     },
#     "items": [
#       {
#         "item_number": "001",
#         "id": "10dddc65-c4a1-4cc3-900a-3532dd69309f",
#         "created": {
#           "$date": 1760256000000
#         },
#         "updated": {
#           "$date": 1760256000000
#         },
#         "barcode": "4809992000101",
#         "type": "fuel",
#         "name": "Premium Gasoline",
#         "price": 69.5,
#         "unit": "liter",
#         "previous_quantity": 520,
#         "addstock": 300,
#         "sold": 250,
#         "current_quantity": 570
#       },
#       {
#         "item_number": "002",
#         "id": "12ef013e-40d3-4fdf-a640-e507ff22a658",
#         "created": {
#           "$date": 1760256000000
#         },
#         "updated": {
#           "$date": 1760256000000
#         },
#         "barcode": "4809992000102",
#         "type": "fuel",
#         "name": "Regular Gasoline",
#         "price": 64.75,
#         "unit": "liter",
#         "previous_quantity": 680,
#         "addstock": 400,
#         "sold": 320,
#         "current_quantity": 760
#       },
#       {
#         "item_number": "003",
#         "id": "8bf6ec46-4710-4a21-9369-a85109d7fcd3",
#         "created": {
#           "$date": 1760256000000
#         },
#         "updated": {
#           "$date": 1760256000000
#         },
#         "barcode": "4809992000103",
#         "type": "fuel",
#         "name": "Premium Diesel",
#         "price": 61.2,
#         "unit": "liter",
#         "previous_quantity": 450,
#         "addstock": 350,
#         "sold": 280,
#         "current_quantity": 520
#       },
#       {
#         "item_number": "004",
#         "id": "0472c253-7cbe-4966-aae9-cc16d9145967",
#         "created": {
#           "$date": 1760256000000
#         },
#         "updated": {
#           "$date": 1760256000000
#         },
#         "barcode": "4809992000201",
#         "type": "lubricant",
#         "name": "Engine Oil SAE 40",
#         "price": 250.0,
#         "unit": "liter",
#         "previous_quantity": 60,
#         "addstock": 40,
#         "sold": 25,
#         "current_quantity": 75
#       },
#       {
#         "item_number": "005",
#         "id": "a10a023e-417f-4f39-b269-a2e4b19e7b27",
#         "created": {
#           "$date": 1760256000000
#         },
#         "updated": {
#           "$date": 1760256000000
#         },
#         "barcode": "4809992000202",
#         "type": "lubricant",
#         "name": "Automatic Transmission Fluid (ATF)",
#         "price": 310.0,
#         "unit": "liter",
#         "previous_quantity": 50,
#         "addstock": 30,
#         "sold": 20,
#         "current_quantity": 60
#       },
#       {
#         "item_number": "006",
#         "id": "6c3faa13-f872-4b40-9ef4-6d5e15aeab16",
#         "created": {
#           "$date": 1760256000000
#         },
#         "updated": {
#           "$date": 1760256000000
#         },
#         "barcode": "4809992000203",
#         "type": "lubricant",
#         "name": "Gear Oil EP 90",
#         "price": 285.0,
#         "unit": "liter",
#         "previous_quantity": 45,
#         "addstock": 25,
#         "sold": 15,
#         "current_quantity": 55
#       },
#       {
#         "item_number": "007",
#         "id": "d4a43eb3-8c73-45ac-88d2-23b83f557fb5",
#         "created": {
#           "$date": 1760256000000
#         },
#         "updated": {
#           "$date": 1760256000000
#         },
#         "barcode": "4809992000204",
#         "type": "lubricant",
#         "name": "Hydraulic Oil ISO 68",
#         "price": 295.0,
#         "unit": "liter",
#         "previous_quantity": 35,
#         "addstock": 25,
#         "sold": 10,
#         "current_quantity": 50
#       },
#       {
#         "item_number": "008",
#         "id": "81bb9e28-3bc0-46e1-8eaa-35fa0ae5425d",
#         "created": {
#           "$date": 1760256000000
#         },
#         "updated": {
#           "$date": 1760256000000
#         },
#         "barcode": "4809992000205",
#         "type": "lubricant",
#         "name": "2T Motorcycle Oil",
#         "price": 180.0,
#         "unit": "liter",
#         "previous_quantity": 80,
#         "addstock": 60,
#         "sold": 45,
#         "current_quantity": 95
#       }
#     ],
#     "cashier": "Liam Santos",
#     "cashier_employee_number": "50321",
#     "recorder": "Ella Reyes",
#     "recorder_employee_number": "50325",
#     "is_empty": false
#   },
#   {
#     "id": "956598bb-5d3d-47de-87d7-136a46020529",
#     "previous_form_qr_code": "20251012",
#     "current_form_qr_code": "42214212",
#     "date": "2025-10-13",
#     "location": "JEF Gas Station \u2013 Sikatuna Branch",
#     "tin": "123-456-789",
#     "branch": "JEF Biosciences Fuel Division",
#     "generated_by": "Ella Reyes",
#     "generator_employee_number": "50325",
#     "created": {
#       "$date": 1760643716313
#     },
#     "items": [
#       {
#         "item_number": "001",
#         "id": "0522679f-d1b3-4497-84ac-ca7f833ea080",
#         "created": {
#           "$date": 1760643717626
#         },
#         "updated": {
#           "$date": 1760643717626
#         },
#         "barcode": "4809992000101",
#         "type": "fuel",
#         "name": "Premium Gasoline",
#         "price": 69.5,
#         "unit": "liter",
#         "previous_quantity": 570,
#         "addstock": 0,
#         "sold": 0,
#         "current_quantity": 0
#       },
#       {
#         "item_number": "002",
#         "id": "fb8e82d7-f1b7-4169-a4ab-9ac3ad3b9a6b",
#         "created": {
#           "$date": 1760643717626
#         },
#         "updated": {
#           "$date": 1760643717626
#         },
#         "barcode": "4809992000102",
#         "type": "fuel",
#         "name": "Regular Gasoline",
#         "price": 64.75,
#         "unit": "liter",
#         "previous_quantity": 760,
#         "addstock": 0,
#         "sold": 0,
#         "current_quantity": 0
#       },
#       {
#         "item_number": "003",
#         "id": "3ecb2077-b440-4976-ad25-109741ce08f2",
#         "created": {
#           "$date": 1760643717626
#         },
#         "updated": {
#           "$date": 1760643774536
#         },
#         "barcode": "4809992000103",
#         "type": "fuel",
#         "name": "Premium Diesel",
#         "price": 61.2,
#         "unit": "liter",
#         "previous_quantity": 520,
#         "addstock": 20.0,
#         "sold": 0.0,
#         "current_quantity": 540.0
#       },
#       {
#         "item_number": "004",
#         "id": "e0b83d1f-dba5-4962-9aa7-6f7055c076f6",
#         "created": {
#           "$date": 1760643717626
#         },
#         "updated": {
#           "$date": 1760643717626
#         },
#         "barcode": "4809992000201",
#         "type": "lubricant",
#         "name": "Engine Oil SAE 40",
#         "price": 250,
#         "unit": "liter",
#         "previous_quantity": 75,
#         "addstock": 0,
#         "sold": 0,
#         "current_quantity": 0
#       },
#       {
#         "item_number": "005",
#         "id": "282ffe38-0682-452a-8189-6f959120d759",
#         "created": {
#           "$date": 1760643717626
#         },
#         "updated": {
#           "$date": 1760643717626
#         },
#         "barcode": "4809992000202",
#         "type": "lubricant",
#         "name": "Automatic Transmission Fluid (ATF)",
#         "price": 310,
#         "unit": "liter",
#         "previous_quantity": 60,
#         "addstock": 0,
#         "sold": 0,
#         "current_quantity": 0
#       },
#       {
#         "item_number": "006",
#         "id": "d3b97b3b-6ee1-4ef7-a2fa-e85044fe9765",
#         "created": {
#           "$date": 1760643717626
#         },
#         "updated": {
#           "$date": 1760643717626
#         },
#         "barcode": "4809992000203",
#         "type": "lubricant",
#         "name": "Gear Oil EP 90",
#         "price": 285,
#         "unit": "liter",
#         "previous_quantity": 55,
#         "addstock": 0,
#         "sold": 0,
#         "current_quantity": 0
#       },
#       {
#         "item_number": "007",
#         "id": "c6f987aa-6a4e-476f-bb81-cc7d9d7d9df8",
#         "created": {
#           "$date": 1760643717626
#         },
#         "updated": {
#           "$date": 1760643717626
#         },
#         "barcode": "4809992000204",
#         "type": "lubricant",
#         "name": "Hydraulic Oil ISO 68",
#         "price": 295,
#         "unit": "liter",
#         "previous_quantity": 50,
#         "addstock": 0,
#         "sold": 0,
#         "current_quantity": 0
#       },
#       {
#         "item_number": "008",
#         "id": "df2e8c3b-dcde-40eb-a317-717b6acee1b3",
#         "created": {
#           "$date": 1760643717626
#         },
#         "updated": {
#           "$date": 1760643717626
#         },
#         "barcode": "4809992000205",
#         "type": "lubricant",
#         "name": "2T Motorcycle Oil",
#         "price": 180,
#         "unit": "liter",
#         "previous_quantity": 95,
#         "addstock": 0,
#         "sold": 0,
#         "current_quantity": 0
#       }
#     ],
#     "is_empty": true
#   }
# ]
