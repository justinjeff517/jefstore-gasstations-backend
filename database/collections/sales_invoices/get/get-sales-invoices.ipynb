# %%
import os, json
from datetime import datetime, timezone
from dotenv import load_dotenv
from pymongo import MongoClient
from bson.decimal128 import Decimal128

load_dotenv()
uri = os.getenv("MONGODB_URI")
database = os.getenv("MONGODB_DATABASE")

client = MongoClient(uri, tz_aware=True)
coll = client[database]["sales_invoices"]

def _enc(o):
    if isinstance(o, Decimal128):
        return str(o.to_decimal())
    if isinstance(o, datetime):
        return o.astimezone(timezone.utc).isoformat().replace("+00:00", "Z")
    return str(o)

docs = list(coll.find({}, {"_id": 0}))
print(json.dumps(docs, indent=2, ensure_ascii=False, default=_enc))
# Out:
# [
#   {
#     "id": "8f6a2e4b-3d9a-4f2f-9c2a-7b1a0f4c9d31",
#     "current_form_qr_code": "20251012",
#     "previous_form_qr_code": "20251011",
#     "tin": "123-456-789",
#     "location": "JEF Gas Station – Sikatuna Branch",
#     "created": "2025-10-12T12:45:00Z",
#     "date": "2025-10-12",
#     "items": [
#       {
#         "receipt_number": "20251012-00012345",
#         "customer_name": "Juan Dela Cruz",
#         "type": "fuel",
#         "vatable_sales": 2456.7,
#         "vat_amount": 293.8,
#         "total_amount": 2750.5
#       },
#       {
#         "receipt_number": "20251012-00012346",
#         "customer_name": "ACME Logistics Inc.",
#         "type": "lubricant",
#         "vatable_sales": 875.0,
#         "vat_amount": 105.0,
#         "total_amount": 980.0
#       },
#       {
#         "receipt_number": "20251012-00012347",
#         "customer_name": "Maria Santos",
#         "type": "fuel",
#         "vatable_sales": 1339.29,
#         "vat_amount": 160.71,
#         "total_amount": 1500.0
#       },
#       {
#         "receipt_number": "20251012-00012348",
#         "customer_name": "Walk-in",
#         "type": "fuel",
#         "vatable_sales": 1117.63,
#         "vat_amount": 133.12,
#         "total_amount": 1250.75
#       },
#       {
#         "receipt_number": "20251012-00012349",
#         "customer_name": "Bohol Auto Care",
#         "type": "lubricant",
#         "vatable_sales": 312.5,
#         "vat_amount": 37.5,
#         "total_amount": 350.0
#       },
#       {
#         "receipt_number": "20251012-00012350",
#         "customer_name": "Roadrunner Transport",
#         "type": "lubricant",
#         "vatable_sales": 1607.14,
#         "vat_amount": 192.86,
#         "total_amount": 1800.0
#       }
#     ],
#     "cashier_employee_number": "50321",
#     "cashier": "Mike Row",
#     "recorder_employee_number": "50325",
#     "recorder": "Michael Phelps",
#     "is_empty": false
#   },
#   {
#     "id": "2b877c11-acbc-40f4-80c5-9bd13bb2d71f",
#     "previous_form_qr_code": "20251012",
#     "current_form_qr_code": "20251013",
#     "tin": "123-456-789",
#     "location": "JEF Gas Station – Sikatuna Branch",
#     "created": "2025-10-13T16:47:15.802597+00:00",
#     "date": "2025-10-13",
#     "is_empty": false,
#     "cashier": "John Smith",
#     "cashier_employee_number": "10001",
#     "items": [
#       {
#         "receipt_number": "123",
#         "customer_name": "Markus",
#         "type": "fuel",
#         "vatable_sales": "1111",
#         "vat_amount": "133.32",
#         "total_amount": "1244.32"
#       },
#       {
#         "receipt_number": "222",
#         "customer_name": "Just",
#         "type": "fuel",
#         "vatable_sales": "22222",
#         "vat_amount": "2666.64",
#         "total_amount": "24888.64"
#       }
#     ],
#     "recorder": "David Williams",
#     "recorder_employee_number": "10003",
#     "updated_at": "2025-10-13T16:47:42.443442+00:00"
#   },
#   {
#     "id": "2b877c11-acbc-40f4-80c5-9bd13bb2d71f",
#     "previous_form_qr_code": "20251012",
#     "current_form_qr_code": "20251013",
#     "tin": "123-456-789",
#     "location": "JEF Gas Station – Sikatuna Branch",
#     "created": "2025-10-13T16:50:12.580820+00:00",
#     "date": "2025-10-13",
#     "is_empty": false,
#     "items": [
#       {
#         "receipt_number": "123",
#         "customer_name": "Markus",
#         "type": "fuel",
#         "vatable_sales": "1111",
#         "vat_amount": "133.32",
#         "total_amount": "1244.32"
#       },
#       {
#         "receipt_number": "222",
#         "customer_name": "Just",
#         "type": "fuel",
#         "vatable_sales": "22222",
#         "vat_amount": "2666.64",
#         "total_amount": "24888.64"
#       }
#     ],
#     "cashier": "John Smith",
#     "cashier_employee_number": "10001",
#     "recorder": "David Williams",
#     "recorder_employee_number": "10003",
#     "updated_at": "2025-10-13T16:50:43.080217+00:00"
#   },
#   {
#     "id": "2b877c11-acbc-40f4-80c5-9bd13bb2d71f",
#     "previous_form_qr_code": "20251012",
#     "current_form_qr_code": "20251013",
#     "tin": "123-456-789",
#     "location": "JEF Gas Station – Sikatuna Branch",
#     "created": "2025-10-13T16:50:43.138176+00:00",
#     "date": "2025-10-13",
#     "items": [
#       {
#         "receipt_number": "123",
#         "customer_name": "Markus",
#         "type": "fuel",
#         "vatable_sales": "1111",
#         "vat_amount": "133.32",
#         "total_amount": "1244.32"
#       },
#       {
#         "receipt_number": "222",
#         "customer_name": "Just",
#         "type": "fuel",
#         "vatable_sales": "22222",
#         "vat_amount": "2666.64",
#         "total_amount": "24888.64"
#       }
#     ],
#     "is_empty": false,
#     "cashier": "John Smith",
#     "cashier_employee_number": "10001",
#     "recorder": "David Williams",
#     "recorder_employee_number": "10003",
#     "updated_at": "2025-10-13T16:50:47.363418+00:00"
#   },
#   {
#     "id": "2b877c11-acbc-40f4-80c5-9bd13bb2d71f",
#     "previous_form_qr_code": "20251012",
#     "current_form_qr_code": "20251013",
#     "tin": "123-456-789",
#     "location": "JEF Gas Station – Sikatuna Branch",
#     "created": "2025-10-13T16:50:47.420798+00:00",
#     "date": "2025-10-13",
#     "items": [
#       {
#         "receipt_number": "123",
#         "customer_name": "Markus",
#         "type": "fuel",
#         "vatable_sales": "1111",
#         "vat_amount": "133.32",
#         "total_amount": "1244.32"
#       },
#       {
#         "receipt_number": "222",
#         "customer_name": "Just",
#         "type": "fuel",
#         "vatable_sales": "22222",
#         "vat_amount": "2666.64",
#         "total_amount": "24888.64"
#       }
#     ],
#     "is_empty": false,
#     "cashier": "John Smith",
#     "cashier_employee_number": "10001",
#     "recorder": "David Williams",
#     "recorder_employee_number": "10003",
#     "updated_at": "2025-10-13T16:51:19.839559+00:00"
#   },
#   {
#     "id": "12ed61cc-5ced-4f2c-b503-4f066b49d979",
#     "previous_form_qr_code": "20251013",
#     "current_form_qr_code": "20251013",
#     "tin": "123-456-789",
#     "location": "JEF Gas Station – Sikatuna Branch",
#     "created": "2025-10-13T16:51:19.899417+00:00",
#     "date": "2025-10-14",
#     "items": [],
#     "is_empty": true
#   }
# ]
